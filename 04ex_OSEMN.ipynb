# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed = 123

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
my_array = np.random.randn(10)
with open("/Users/tommaso/Desktop/MagistraleI/Python/LaboratoryOfComputationalPhysics_Y4/lab_data/simple_data.txt", mode='w') as f:
    for i in my_array:
        f.write(str(i) + "\n")

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
my_matrix = np.random.randn(5, 5)
with open("/Users/tommaso/Desktop/MagistraleI/Python/LaboratoryOfComputationalPhysics_Y4/lab_data/data.txt", mode='w') as f:
    for i in range(my_matrix.shape[0]):
        for j in range(my_matrix.shape[1]):
            f.write(str(my_matrix[i,j]) + "\n")
        f.write("\n")

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
with open("/Users/tommaso/Desktop/MagistraleI/Python/LaboratoryOfComputationalPhysics_Y4/lab_data/data.txt", mode='r') as f:
     with open("/Users/tommaso/Desktop/MagistraleI/Python/LaboratoryOfComputationalPhysics_Y4/lab_data/data.csv", mode='w') as fcsv:
        my_string = ""
        for j in f:
            if j != "\n":
                my_string += str(float(j)) + ","
                continue
            elif j == "\n":
                fcsv.write(my_string[:-1] + "\n")
                my_string = ""

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
with  open('/Users/tommaso/Desktop/MagistraleI/Python/LaboratoryOfComputationalPhysics_Y4/lab_data/credit_card.dat','rb') as file:
    credit_cards = ""
    my_file = file.read()
    for i in my_file:
        credit_cards += chr(i)
    bin_numbers = ""
    credit_cards_numbers = ""
    numbers_lenght = 6
    for i in credit_cards:
        if i != "\n":
            bin_numbers += i
            continue
        else:
            for j in range(len(bin_numbers[:-4]))[::6]:
                credit_cards_numbers += chr(int(bin_numbers[j:j+6], 2))
            credit_cards_numbers += "\n"
            bin_numbers = ""
print('Credit card numbers:' + '\n' + credit_cards_numbers)
# Out:
# Credit card numbers:
# 7648 5673 3775 2271
# 3257 8247 3354 2266
# 2722 0001 4011 6652
# 0661 3063 3742 3150
# 0432 1608 1462 4742
# 5827 2027 8785 7303
# 5774 8528 2087 1117
# 8140 1210 6352 2845
# 5764 1133 7301 7100
# 6456 1737 4126 6726
# 1228 8631 7382 0000
# 7051 0160 5374 3166
# 0618 3587 1630 6376
# 1545 5454 7444 5636
# 6735 3116 3202 6834
# 7287 5011 1547 8413
# 7033 2607 3328 4200
# 2568 5244 1874 5024
# 1684 2253 7570 7118
# 0672 2576 0575 6631
# 6332 8353 8787 1340
# 1813 3361 1175 4211
# 2477 6450 8840 2368
# 5512 3505 2563 1326
# 3083 7882 0621 0025
# 4521 5148 8045 0334
# 7563 3654 8713 5787
# 8324 2664 0476 5561
# 0565 2504 7168 3510
# 5107 5507 1767 0738
# 2462 1821 2448 1443
# 2788 0638 6861 6554
# 5851 5873 5474 0547
# 0670 1004 4013 2655
# 5874 5506 3048 0806
# 2805 5401 8462 1260
# 5083 8406 6310 1862
# 1076 1445 3013 2266
# 8440 4804 4844 5277
# 4758 6141 0686 1387
# 7586 0675 0315 2568
# 2544 1258 7432 5165
# 3474 5023 4434 5626
# 1410 0270 0434 5086
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %%
import json
import pandas as pd
data = json.load(open('lab_data/user_data.json'))
american_express_list = [i for i in data if i['CreditCardType'] == 'American Express']
print("All the American Express users: \n", american_express_list)
# Just to check if the code ran succesfully
print("\nCard type of the filtered data: \n")
print([i['CreditCardType'] for i in american_express_list])
csv_string = ""
for i in american_express_list:
    for j in i.keys():
        if j != 'CreditCardType':
            csv_string += i[j]
            csv_string += ","
            continue
        else:
            csv_string += i[j]
    csv_string += "\n"    
    
print("\n" + "csv file text:\n" + csv_string)
# Out:
# All the American Express users:
# ...

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %%
import pandas as pd
url = "https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
data = pd.read_csv(url)
print('Data info:\n')
pd.DataFrame.info(data)
data.hist("class", bins = 25)
# Out:
# Data info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int64
#  1   cap-shape                 8124 non-null   int64
#  2   cap-surface               8124 non-null   int64
#  3   cap-color                 8124 non-null   int64
#  4   bruises                   8124 non-null   int64
#  5   odor                      8124 non-null   int64
#  6   gill-attachment           8124 non-null   int64
#  7   gill-spacing              8124 non-null   int64
#  8   gill-size                 8124 non-null   int64
#  9   gill-color                8124 non-null   int64
#  10  stalk-shape               8124 non-null   int64
#  11  stalk-root                8124 non-null   int64
#  12  stalk-surface-above-ring  8124 non-null   int64
# ...

# %% [markdown]
# **We see how only two values are present.**

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %%
url = "https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1"
data = pd.read_csv(url)
print('Data info: \n')
pd.DataFrame.info(data)
# Out:
# Data info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   label        2000 non-null   float64
#  1   features_1   2000 non-null   float64
#  2   features_2   2000 non-null   float64
#  3   features_3   2000 non-null   float64
#  4   features_4   2000 non-null   float64
#  5   features_5   2000 non-null   float64
#  6   features_6   2000 non-null   float64
#  7   features_7   2000 non-null   float64
#  8   features_8   2000 non-null   float64
#  9   features_9   2000 non-null   float64
#  10  features_10  2000 non-null   float64
#  11  features_11  2000 non-null   float64
#  12  features_12  2000 non-null   float64
#  13  features_13  2000 non-null   float64
#  14  features_14  2000 non-null   float64
#  15  features_15  2000 non-null   float64
#  16  features_16  2000 non-null   float64
# ...

# %%
fig, ax = plt.subplots(nrows= 3, ncols=1, figsize=(7, 20))
ax[0].scatter(data['features_1'],data['features_2'], edgecolor='black', label='Data points')
ax[0].set_title('feature 1 and feature 2 plot', fontsize=20)
ax[0].set_ylabel('y', fontsize=15) 
ax[0].set_xlabel('x', fontsize=15)
ax[0].minorticks_on()
ax[0].legend(shadow=True, framealpha=1, facecolor='gainsboro', edgecolor='black', title='Legend', title_fontsize='large', prop={'weight':'bold','size':8}, loc='upper left')

ax[1].scatter(data['features_1'],data['features_3'], edgecolor='black', label='Data points')
ax[1].set_title('feature 1 and feature 3 plot', fontsize=20)
ax[1].minorticks_on()
ax[1].set_ylabel('y', fontsize=15) 
ax[1].set_xlabel('x', fontsize=15)
ax[1].legend(shadow=True, framealpha=1, facecolor='gainsboro', edgecolor='black', title='Legend', title_fontsize='large', prop={'weight':'bold','size':8}, loc='upper left')

ax[2].scatter(data['features_2'],data['features_3'], edgecolor='black', label='Data points')
ax[2].set_title('feature 2 and feature 3 plot', fontsize=20)
ax[2].minorticks_on()
ax[2].set_ylabel('y', fontsize=15) 
ax[2].set_xlabel('x', fontsize=15)
ax[2].legend(shadow=True, framealpha=1, facecolor='gainsboro', edgecolor='black', title='Legend', title_fontsize='large', prop={'weight':'bold','size':8}, loc='upper left')
fig.tight_layout()

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.

# %%
url = "https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1"
data = pd.read_csv(url)
json_format = data.to_json(orient='columns')
print("json sample: \n" + json_format[:500])
# Out:
# json sample:
# {"class":{"0":1,"1":0,"2":0,"3":1,"4":0,"5":0,"6":0,"7":0,"8":1,"9":0,"10":0,"11":0,"12":0,"13":1,"14":0,"15":0,"16":0,"17":1,"18":1,"19":1,"20":0,"21":1,"22":0,"23":0,"24":0,"25":1,"26":0,"27":0,"28":0,"29":0,"30":0,"31":1,"32":0,"33":0,"34":0,"35":0,"36":0,"37":1,"38":0,"39":0,"40":0,"41":0,"42":0,"43":1,"44":0,"45":0,"46":0,"47":0,"48":0,"49":0,"50":0,"51":0,"52":0,"53":1,"54":1,"55":0,"56":0,"57":0,"58":0,"59":0,"60":0,"61":0,"62":0,"63":0,"64":0,"65":0,"66":0,"67":0,"68":0,"69":0,"70":0,"71
